# %% [markdown]
# # Week 10 Homework
#
# Extend the following class and name this class `ModuleLister`
#
# This will find all unique modules in your homework and labs.

# %%
### DON'T CHANGE THIS CELL
import os

class FileProcessor:
    
    def __init__(self, path, file_types=['.ipynb']):
        self.files = self.find_all_files(path, file_types)
        print(f'{len(self.files)} file(s) found...')

    
    def find_all_files(self, path, file_types):
        paths = []
        for root, dirs, files in os.walk(path):
            for file in files:
                if any([file.endswith(ft) for ft in file_types]):
                    path = os.path.join(root, file)
                    # print(path)
                    paths.append(path)
        return paths
    
    def read_file(self, file_path, encoding='utf8'):
        with open(file_path,encoding=encoding) as f:
            return f.read()
    
    def start(self):
        """
        Entry point for the class
        """
        for file in self.files:
            self.process_file(file)
        
    def process_file(self, file_path):
        """
        abstract method
        """
        raise NotImplemented('process_file method not implemented')

# %%
### your code starts here

class ModuleLister(FileProcessor):
    pass

# %%
processor = ModuleLister(path='../') # change the path according to your path
# Out:
# 9 file(s) found...

# %%
processor.start()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-bba35a65086b> in <module>
# ----> 1 processor.start()
#
# <ipython-input-2-8b5552d77d59> in start(self)
#      28         """
#      29         for file in self.files:
# ---> 30             self.process_file(file)
#      31
#      32     def process_file(self, file_path):
#
# <ipython-input-2-8b5552d77d59> in process_file(self, file_path)
#      34         abstract method
#      35         """
# ---> 36         raise NotImplemented('process_file method not implemented')
#
# TypeError: 'NotImplementedType' object is not callable
